# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("dataset.csv")

# %%
df
# Out:
#       feeling.nervous panic breathing.rapidly sweating  \
# 0                 yes   yes               yes      yes
# 1                  no    no                no       no
# 2                  no    no                no       no
# 3                  no    no                no       no
# 4                  no    no                no       no
# ...               ...   ...               ...      ...
# 40955             yes   yes               yes      yes
# 40956              no    no                no       no
# 40957              no    no                no       no
# 40958              no    no                no       no
# 40959              no    no                no       no
#
#       trouble.in.concentration having.trouble.in.sleeping  \
# 0                          yes                        yes
# 1                           no                         no
# 2                           no                         no
# 3                           no                         no
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=40960, step=1)

# %%
Y = df['Disorder'].copy()

# %%
for column in df.columns:
    df[column] = df[column].map({'yes' : 1, 'no' : 0})

# %%
df.drop('Disorder', axis = 1, inplace = True)

# %%
df.dtypes
# Out:
# feeling.nervous                int64
# panic                          int64
# breathing.rapidly              int64
# sweating                       int64
# trouble.in.concentration       int64
# having.trouble.in.sleeping     int64
# having.trouble.with.work       int64
# hopelessness                   int64
# anger                          int64
# over.react                     int64
# change.in.eating               int64
# suicidal.thought               int64
# feeling.tired                  int64
# close.friend                   int64
# social.media.addiction         int64
# weight.gain                    int64
# material.possessions           int64
# introvert                      int64
# popping.up.stressful.memory    int64
# having.nightmares              int64
# avoids.people.or.activities    int64
# feeling.negative               int64
# trouble.concentrating          int64
# blamming.yourself              int64
# dtype: object

# %%
Y
# Out:
# 0           Anxiety
# 1        Depression
# 2        Loneliness
# 3            Stress
# 4            Normal
#             ...
# 40955       Anxiety
# 40956    Depression
# 40957    Loneliness
# 40958        Stress
# 40959        Normal
# Name: Disorder, Length: 40960, dtype: object

# %%
Y.nunique()
# Out:
# 5

# %%
Y.unique()
# Out:
# array(['Anxiety', 'Depression', 'Loneliness', 'Stress', 'Normal'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
m = LabelEncoder()
Y = m.fit_transform(Y)
print(m.get_params)
# Out:
# <bound method BaseEstimator.get_params of LabelEncoder()>

# %%
Y
# Out:
# array([0, 1, 2, ..., 2, 4, 3], dtype=int64)

# %%
output
# Out:
# array([0, 1, 2, ..., 2, 4, 3])

# %%
X = np.array(df)

# %%
from sklearn.model_selection import train_test_split

# %%
help(train_test_split)
# Out:
# Help on function train_test_split in module sklearn.model_selection._split:
#
# train_test_split(*arrays, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)
#     Split arrays or matrices into random train and test subsets.
#
#     Quick utility that wraps input validation,
#     ``next(ShuffleSplit().split(X, y))``, and application to input data
#     into a single call for splitting (and optionally subsampling) data into a
#     one-liner.
#
#     Read more in the :ref:`User Guide <cross_validation>`.
#
#     Parameters
#     ----------
#     *arrays : sequence of indexables with same length / shape[0]
#         Allowed inputs are lists, numpy arrays, scipy-sparse
#         matrices or pandas dataframes.
#
#     test_size : float or int, default=None
#         If float, should be between 0.0 and 1.0 and represent the proportion
#         of the dataset to include in the test split. If int, represents the
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
import tensorflow as tf

# %%
model = tf.keras.Sequential()

# %%
model.add(tf.keras.layers.Dense(24, activation = 'tanh'))
model.add(tf.keras.layers.Dense(16, activation = 'tanh'))
model.add(tf.keras.layers.Dense(10, activation = 'tanh'))
model.add(tf.keras.layers.Dense(5, activation = 'softmax'))

# %%
model.compile(optimizer = 'adam', loss = tf.keras.losses.SparseCategoricalCrossentropy())

# %%
model.fit(x = X_train, y = Y_train, batch_size = 512, epochs = 200, verbose = 1, validation_split= 0.3)
# Out:
# Epoch 1/200
# 45/45 [==============================] - 1s 12ms/step - loss: 0.9560 - val_loss: 0.5930
# Epoch 2/200
# 45/45 [==============================] - 0s 5ms/step - loss: 0.4216 - val_loss: 0.2834
# Epoch 3/200
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2131 - val_loss: 0.1577
# Epoch 4/200
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1282 - val_loss: 0.1035
# Epoch 5/200
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0883 - val_loss: 0.0747
# Epoch 6/200
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0656 - val_loss: 0.0572
# Epoch 7/200
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0512 - val_loss: 0.0456
# Epoch 8/200
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0414 - val_loss: 0.0374
# Epoch 9/200
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0344 - val_loss: 0.0314
# Epoch 10/200
# ...

# %%
Y
# Out:
# array([0, 1, 2, ..., 2, 4, 3], dtype=int64)

# %%
Y_train
# Out:
# array([2, 1, 4, ..., 0, 1, 3])

# %%
rand = df.sample()

# %%
rand
# Out:
#        feeling.nervous  panic  breathing.rapidly  sweating  \
# 25924                0      0                  0         0
#
#        trouble.in.concentration  having.trouble.in.sleeping  \
# 25924                         0                           0
#
#        having.trouble.with.work  hopelessness  anger  over.react  ...  \
# 25924                         0             0      0           0  ...
#
#        social.media.addiction  weight.gain  material.possessions  introvert  \
# 25924                       0            0                     0          0
#
#        popping.up.stressful.memory  having.nightmares  \
# 25924                            0                  0
#
#        avoids.people.or.activities  feeling.negative  trouble.concentrating  \
# 25924                            0                 0                      0
#
#        blamming.yourself
# 25924                  0
#
# [1 rows x 24 columns]

# %%
act = Y[rand.index]

# %%
act.shape
# Out:
# (1,)

# %%
model.predict(np.array(rand))
# Out:
# 1/1 [==============================] - 0s 27ms/step
# array([[2.6300288e-06, 1.4372972e-05, 1.0902892e-05, 9.9997211e-01,
#         4.2731816e-08]], dtype=float32)

# %%
prediction = model.predict(X_test).argmax(axis = 1)
# Out:
# 256/256 [==============================] - 1s 2ms/step

# %%
print(np.mean(prediction == Y_test) * 100)
# Out:
# 100.0

# %%
model.save("mental_health_status.h5",)

# %%
{0 : "Anxiety", 1 : "Depression", 2 : "Loneliness", 3 : "Normal", 4 : "Stress"}
# Out:
# {0: 'Anxiety', 1: 'Depression', 2: 'Loneliness', 3: 'Normal', 4: 'Stress'}

# %%
Y
# Out:
# array([0, 1, 2, ..., 2, 4, 3], dtype=int64)

# %%
df1 = pd.read_csv("dataset.csv")

# %%
df1
# Out:
#       feeling.nervous panic breathing.rapidly sweating  \
# 0                 yes   yes               yes      yes
# 1                  no    no                no       no
# 2                  no    no                no       no
# 3                  no    no                no       no
# 4                  no    no                no       no
# ...               ...   ...               ...      ...
# 40955             yes   yes               yes      yes
# 40956              no    no                no       no
# 40957              no    no                no       no
# 40958              no    no                no       no
# 40959              no    no                no       no
#
#       trouble.in.concentration having.trouble.in.sleeping  \
# 0                          yes                        yes
# 1                           no                         no
# 2                           no                         no
# 3                           no                         no
# ...
